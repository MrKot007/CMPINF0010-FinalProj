# %% [markdown]
# Welcome! Here were are going to create our super-duper-creative 100% original project for the most useful and engaging class ever!! (pssst, it's CMPINF 0010)
# Please download this file and try committing something to this repo
